# %% [markdown]
# # DiGToR on FMB - end-to-end
#
# Disagreement-Guided Token Routing for RGB-Infrared semantic segmentation.
# Run the cells top to bottom on Colab (Pro / A100) or Kaggle; the notebook is
# self-contained:
#
# 1. Clone the repo.
# 2. Download the FMB dataset from Google Drive and unzip `train.zip` / `test.zip`.
# 3. Train the v_only / t_only teachers, the fusion baseline, and DiGToR (80 epochs each).
# 4. Evaluate on the held-out test split: segmentation mIoU, the thermal rescue
#    protocol, routing analyses, corruption robustness, FLOPs / latency, and the
#    modality-cut check.
#
# All results are written to `results_fmb/*.json`.

# %%
import os
import shutil

repo_name = "DiGToR"

# Nếu thư mục đã tồn tại, xóa đi để chuẩn bị tải mới
if os.path.exists(repo_name):
    print(f"Phát hiện thư mục '{repo_name}' đã tồn tại. Đang xóa...")
    shutil.rmtree(repo_name)
    print("Đã xóa thư mục cũ.")

repo_url = f"https://github.com/nguyenmaiductrong/{repo_name}.git"

print(f"Đang tải repo từ {repo_url}...")
exit_code = os.system(f"git clone {repo_url}")

if exit_code == 0:
    print("Tải thành công. Kiểm tra ở thư mục Output/Working.")
else:
    print("Có lỗi xảy ra khi tải, kiểm tra lại đường dẫn mạng hoặc URL.")
# Out:
# Đang tải repo từ https://github.com/nguyenmaiductrong/DiGToR.git...
# Tải thành công. Kiểm tra ở thư mục Output/Working.

# %%
# repo da duoc clone moi o cell 0 (fresh = latest main); pull nay chi de chac chan
# !cd DiGToR && git pull origin main || echo "(pull skipped - fresh clone already latest)"
# Out:
# From https://github.com/nguyenmaiductrong/DiGToR
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
cd DiGToR
# Out:
# /content/DiGToR

# %%
# --- Download FMB data from Google Drive and unzip train/test ---
# Data is stored OUTSIDE the cloned repo so a re-clone does not wipe it, and the
# step is idempotent: re-running skips the ~1GB download if the data is ready.
import os, glob, zipfile, shutil, subprocess, sys

DRIVE_URL = "https://drive.google.com/drive/folders/1T_jVi80tjgyHTQDpn-TjfySyW4CK1LlF"
FMB_DIR = "/content/FMB" if os.path.isdir("/content") else os.path.join(
    os.path.dirname(os.getcwd()), "FMB")
_mods = ("Visible", "Infrared", "Label")

def _ready(split):
    return all(os.path.isdir(os.path.join(FMB_DIR, split, m)) for m in _mods)

if _ready("train") and _ready("test"):
    print("FMB already prepared at", FMB_DIR)
else:
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "gdown"], check=True)
    import gdown
    dl = os.path.join(os.getcwd(), "_fmb_download")
    shutil.rmtree(dl, ignore_errors=True)
    os.makedirs(dl, exist_ok=True)
    gdown.download_folder(DRIVE_URL, output=dl, quiet=False, use_cookies=False)

    def _find(name):
        hits = glob.glob(os.path.join(dl, "**", name), recursive=True)
        if not hits:
            raise FileNotFoundError(f"{name} not found in the Drive folder")
        return hits[0]

    def _modroot(base):
        # the directory that directly holds Visible/Infrared/Label, whatever the
        # zip's internal nesting is
        for root, _, _ in os.walk(base):
            if all(os.path.isdir(os.path.join(root, m)) for m in _mods):
                return root
        raise FileNotFoundError(f"no Visible/Infrared/Label folder under {base}")

    os.makedirs(FMB_DIR, exist_ok=True)
    for split in ("train", "test"):
        tmp = os.path.join(os.getcwd(), f"_unzip_{split}")
        shutil.rmtree(tmp, ignore_errors=True)
        print(f"unzipping {split}.zip ...")
        with zipfile.ZipFile(_find(f"{split}.zip")) as z:
            z.extractall(tmp)
        dst = os.path.join(FMB_DIR, split)
        shutil.rmtree(dst, ignore_errors=True)
        shutil.move(_modroot(tmp), dst)
        shutil.rmtree(tmp, ignore_errors=True)
    shutil.rmtree(dl, ignore_errors=True)
    print("Prepared FMB at", FMB_DIR)

# The data-detection cell below reads FMB_ROOT first, so this works regardless of
# where the data was staged.
os.environ["FMB_ROOT"] = FMB_DIR
for split in ("train", "test"):
    n = len(glob.glob(os.path.join(FMB_DIR, split, "Label", "*"))) if _ready(split) else 0
    print(f"  {split}: {n} label files")
# Out:
# Retrieving folder contents
# Processing file 1AamLVgMG5JCkhUOZi-xKTymZXCNklnaq test.zip
# Processing file 1nk2R2yZ05SDe2lDpsk2D5RAngMBPUPsB train.zip
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1AamLVgMG5JCkhUOZi-xKTymZXCNklnaq
# From (redirected): https://drive.google.com/uc?id=1AamLVgMG5JCkhUOZi-xKTymZXCNklnaq&confirm=t&uuid=a8d8d9f0-8bf7-4ec8-9e43-b82e38aee1f6
# To: /content/DiGToR/_fmb_download/test.zip
# 100%|██████████| 216M/216M [00:03<00:00, 58.3MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1nk2R2yZ05SDe2lDpsk2D5RAngMBPUPsB
# From (redirected): https://drive.google.com/uc?id=1nk2R2yZ05SDe2lDpsk2D5RAngMBPUPsB&confirm=t&uuid=14241a2d-9fbf-4a8f-95b4-028da38ee58a
# To: /content/DiGToR/_fmb_download/train.zip
# 100%|██████████| 914M/914M [00:16<00:00, 54.5MB/s]
# Download completed
# unzipping train.zip ...
# unzipping test.zip ...
# Prepared FMB at /content/FMB
#   train: 1220 label files
#   test: 280 label files

# %%
# --- Repo + FMB data (auto-detect official train/test split OR legacy flat) ---
# Runs on Colab (Pro / A100) or Kaggle. The previous cell downloads the data and
# sets FMB_ROOT, which is checked first below; the other paths are fallbacks.
import os, sys, glob

REPO = os.getcwd()                 # current dir = the DiGToR repo
assert os.path.isfile(os.path.join(REPO, 'digtor', '__init__.py')),     f'Run this from the DiGToR repo root (no digtor/ package found in {REPO}).'

_mods = ['Visible', 'Infrared', 'Label']

def _is_fmb_root(path):
    flat = all(os.path.isdir(os.path.join(path, s)) for s in _mods)
    split = all(os.path.isdir(os.path.join(path, sp, s)) for sp in ['train', 'test'] for s in _mods)
    return flat or split, split

# Priority: FMB_ROOT (set by the download cell) -> repo/FMB -> Colab /content or
# Drive -> Kaggle inputs.
_candidates = []
if os.environ.get('FMB_ROOT'):
    _candidates.append(os.environ['FMB_ROOT'])
_candidates.append(os.path.join(REPO, 'FMB'))
_candidates += ['/content/FMB', '/content/drive/MyDrive/FMB']
_candidates += glob.glob('/kaggle/input/**/FMB', recursive=True)
_candidates += glob.glob('/kaggle/input/*', recursive=False)

ROOT = None
SPLIT_LAYOUT = False
for _cand in dict.fromkeys(_candidates):
    ok, split = _is_fmb_root(_cand)
    if ok:
        ROOT, SPLIT_LAYOUT = _cand, split
        break
assert ROOT is not None, 'FMB data not found: need flat Visible/Infrared/Label OR official train/test layout.'

print('FMB layout =', 'official train/test (held-out test)' if SPLIT_LAYOUT else 'legacy flat (auto-split)')
print('REPO =', REPO)
print('ROOT =', ROOT)

sys.path.insert(0, REPO)
import torch
print('CUDA:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else '')
# Out:
# FMB layout = official train/test (held-out test)
# REPO = /content/DiGToR
# ROOT = /content/FMB
# CUDA: True NVIDIA L4

# %%
# --- Hyper-parameters: Phase-0 hard-seg-loss forced paths ---
# Pinned to the successful Phase-0 UNet rig: a 3-path DiGToR router
# (V-trust / T-rescue / Joint), rel_gate OFF at eval, hard seg_loss on
# force_path='v'/'t' plus teacher KD (--lambda_distill 0.5).
# The digtor.dataset.fmb loader uses the no-leakage data contract:
# FMB/train -> train+val only, FMB/test -> held-out evaluation.
import os
from digtor.models import build_model

# Guardrail: if this fails, the Kaggle clone is not on the expected 3-path code.
_probe = build_model('digtor', base=8)
assert getattr(_probe.router[-1], 'out_channels', None) == 3, 'Expected the 3-path DiGToR router.'
del _probe

H, W, BASE = 384, 512, 32
BS = 8
EPOCHS = 80
DIGTOR_EPOCHS = 80
CKPT, RES = 'ckpt_fmb', 'results_fmb'
AMP = '--amp'                      # set '' to disable mixed precision
LR = '--lr 5e-4'
IGNORE_BG = '--ignore_bg'          # match the G1/reporting convention; set '' to include class 0
CORRUPT = '--corrupt_aug --corrupt_p 0.5'
DISTILL = '--lambda_distill 0.5'   # hard seg-loss forced paths + KD when teachers exist
NOGATE = '--disable_gate'          # train/eval with reliability gate OFF (rel_gate=0)
GAMMA_PRIOR = '--gamma_prior 2.0'
LAMBDA_COST = '--lambda_cost 0.1'
ROUTE_BETA = '--route_beta 0.7'

# DRY RUN: set LIMIT='8' to smoke-test all cells quickly; set '' for full train/test.
LIMIT = ''
LIMIT_ARG = f'--limit {LIMIT}' if LIMIT else ''
if LIMIT:
    os.environ['FMB_LIMIT'] = LIMIT
    EPOCHS = DIGTOR_EPOCHS = 1
else:
    os.environ.pop('FMB_LIMIT', None)

os.makedirs(CKPT, exist_ok=True)
os.makedirs(RES, exist_ok=True)
print('config:', dict(H=H, W=W, BASE=BASE, BS=BS, EPOCHS=EPOCHS,
                      DIGTOR_EPOCHS=DIGTOR_EPOCHS, CKPT=CKPT, RES=RES,
                      LIMIT=LIMIT or 'full', lr=LR,
                      ignore_bg=bool(IGNORE_BG), corrupt_aug=CORRUPT,
                      distill=DISTILL, gate='off', route_beta=ROUTE_BETA))
# Out:
# config: {'H': 384, 'W': 512, 'BASE': 32, 'BS': 8, 'EPOCHS': 80, 'DIGTOR_EPOCHS': 80, 'CKPT': 'ckpt_fmb', 'RES': 'results_fmb', 'LIMIT': 'full', 'lr': '--lr 5e-4', 'ignore_bg': True, 'corrupt_aug': '--corrupt_aug --corrupt_p 0.5', 'distill': '--lambda_distill 0.5', 'gate': 'off', 'route_beta': '--route_beta 0.7'}

# %%
# --- Weights & Biases: checkpoint sync (survive Colab disconnects) ---
# Logs metrics and uploads each best checkpoint as a wandb artifact (<mode>-ckpt).
# A dropped session can pull them back (next cell) so finished models are reused
# instead of retrained. Set USE_WANDB=False to disable everything.
import os, subprocess, sys

USE_WANDB = True
WB_PROJECT = 'digtor-fmb'
WB_ENTITY = None            # None = your default wandb entity

if USE_WANDB:
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'wandb'], check=True)
    import wandb
    # Kaggle: add your key as a secret named WANDB_API_KEY. Colab: this prompts
    # once, or set os.environ['WANDB_API_KEY'] = '...' before running.
    try:
        wandb.login()
    except Exception as e:
        print('wandb.login failed -> disabling wandb:', e); USE_WANDB = False

WANDB = (f'--wandb --wandb_project {WB_PROJECT}'
         + (f' --wandb_entity {WB_ENTITY}' if WB_ENTITY else '')) if USE_WANDB else ''
ENTITY_ARG = f'--entity {WB_ENTITY}' if WB_ENTITY else ''
print('wandb:', 'ON' if USE_WANDB else 'OFF', '| WANDB =', repr(WANDB))
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter: ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nguyenmaiductrong37 (nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ON | WANDB = '--wandb --wandb_project digtor-fmb'

# %%
# --- Pull any already-trained checkpoints from wandb into CKPT ---
# Idempotent + failsafe: missing artifacts are skipped. After this, each training
# cell's `[ -f {CKPT}/x.pt ]` guard reuses whatever was recovered instead of
# retraining. Run this first on a fresh runtime to resume a dropped session.
if USE_WANDB:
    # !python -m digtor.wandb_ckpt --dataset fmb --pull --project {WB_PROJECT} {ENTITY_ARG} --out {CKPT} --modes v_only t_only fusion digtor
else:
    print('wandb OFF -> skipping checkpoint pull')
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# [wandb] pull v_only: not found / error (project 'digtor-fmb' not found under entity 'nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng')
# [wandb] pull t_only: not found / error (project 'digtor-fmb' not found under entity 'nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng')
# [wandb] pull fusion: not found / error (project 'digtor-fmb' not found under entity 'nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng')
# [wandb] pull digtor: not found / error (project 'digtor-fmb' not found under entity 'nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng')
# [wandb] pulled 0/4 checkpoints: []

# %%
# --- A100 speed knobs (quality-neutral) ---
# channels_last + persistent dataloader workers are always on in the code. Here
# we add torch.compile (fuses the conv graph -> faster GPU step) and match the
# worker count to the host CPU cores so the GPU is never starved waiting on JPEG
# decode. None of this changes the maths, so results are preserved.
import os as _os
WORKERS = f"--workers {min(8, (_os.cpu_count() or 4))}"
COMPILE = '--compile'        # set '' to skip torch.compile (e.g. if it errors)
SPEED = f'{COMPILE} {WORKERS}'.strip()
#
# OPTIONAL, NOT quality-neutral: a bigger batch fills the A100 better but changes
# the optimisation. If you raise BS, scale LR by the same factor (linear scaling
# rule) to keep accuracy, e.g. BS=16 -> LR='--lr 1e-3'. Left at the pinned BS=8.
# BS = 16; LR = '--lr 1e-3'
print('SPEED =', repr(SPEED))
# Out:
# SPEED = '--compile --workers 8'

# %%
# --- Optional: stage matching Phase-0 checkpoints from an attached Kaggle Dataset ---
# Default is OFF because this notebook reruns training on the new split.
# Turn on only when the attached checkpoint dataset was trained with this same
# Phase-0 code and the same train/test split.
import glob, os, shutil

USE_INPUT_CKPTS = False
os.makedirs(CKPT, exist_ok=True)

def _stage(name):
    dst = os.path.join(CKPT, name)
    if os.path.exists(dst):
        print(f'[stage] {name}: already in {CKPT}/')
        return
    hits = [h for h in glob.glob(f'/kaggle/input/**/{name}', recursive=True)
            if 'mit' not in h.lower() and 'detector2' not in h.lower()]
    if hits:
        shutil.copy(hits[0], dst)
        print(f'[stage] {name} <- {hits[0]}')
    else:
        print(f'[stage] {name}: not found -> will train')

if USE_INPUT_CKPTS:
    for _n in ['v_only.pt', 't_only.pt', 'fusion.pt', 'digtor.pt']:
        _stage(_n)
else:
    print('[stage] checkpoint staging disabled; training/eval will use local outputs only')
# Out:
# [stage] checkpoint staging disabled; training/eval will use local outputs only

# %%
# Step 1 - V-only teacher (clean reference, train/val from FMB/train only)
![ -f {CKPT}/v_only.pt ] && echo "[skip] {CKPT}/v_only.pt exists - reusing" || python -m digtor.train --dataset fmb --root {ROOT} --mode v_only --epochs {EPOCHS} --bs {BS} --height {H} --width {W} --base {BASE} --out {CKPT} {AMP} {LR} {IGNORE_BG} {WANDB} {SPEED}
# Out:
# [fmb-train] mode=v_only device=cuda size=(384,512)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: nguyenmaiductrong37 (nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run u6apraec (0.5s)
# wandb: ⣯ setting up run u6apraec (0.5s)
# wandb: ⣟ setting up run u6apraec (0.5s)
# wandb: ⡿ setting up run u6apraec (0.5s)
# wandb: ⢿ setting up run u6apraec (0.5s)
# wandb: ⣻ setting up run u6apraec (1.0s)
# wandb: Tracking run with wandb version 0.27.1
# wandb: Run data is saved locally in /content/DiGToR/wandb/run-20260609_233208-u6apraec
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run v_only
# wandb: ⭐️ View project at https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb
# wandb: 🚀 View run at https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb/runs/u6apraec
# [fmb-train] split: train=1092 val=128 test=280
# [fmb-train] torch.compile enabled
# W0609 23:32:27.493000 3413 torch/_inductor/utils.py:1731] [0/0] Not enough SMs to use max_autotune_gemm mode
# epoch 000 loss=2.3941 val_mIoU=0.1742 mAcc=0.2438 FWIoU=0.5182 (99.7s)
#   -> saved best (mIoU=0.1742)
# epoch 001 loss=1.7623 val_mIoU=0.1935 mAcc=0.2534 FWIoU=0.5716 (17.4s)
#   -> saved best (mIoU=0.1935)
# epoch 002 loss=1.5465 val_mIoU=0.2174 mAcc=0.2803 FWIoU=0.6180 (17.8s)
#   -> saved best (mIoU=0.2174)
# epoch 003 loss=1.4344 val_mIoU=0.2238 mAcc=0.2948 FWIoU=0.6375 (17.8s)
#   -> saved best (mIoU=0.2238)
# epoch 004 loss=1.3604 val_mIoU=0.2319 mAcc=0.2953 FWIoU=0.6372 (17.6s)
#   -> saved best (mIoU=0.2319)
# epoch 005 loss=1.3057 val_mIoU=0.2402 mAcc=0.3063 FWIoU=0.6516 (17.8s)
#   -> saved best (mIoU=0.2402)
# epoch 006 loss=1.2542 val_mIoU=0.2353 mAcc=0.3086 FWIoU=0.6359 (17.8s)
# epoch 007 loss=1.2132 val_mIoU=0.2929 mAcc=0.3629 FWIoU=0.6817 (17.8s)
#   -> saved best (mIoU=0.2929)
# epoch 008 loss=1.1708 val_mIoU=0.3140 mAcc=0.3840 FWIoU=0.6724 (17.7s)
#   -> saved best (mIoU=0.3140)
# epoch 009 loss=1.1399 val_mIoU=0.3263 mAcc=0.4054 FWIoU=0.7062 (17.8s)
#   -> saved best (mIoU=0.3263)
# epoch 010 loss=1.1238 val_mIoU=0.3385 mAcc=0.4071 FWIoU=0.7190 (17.8s)
#   -> saved best (mIoU=0.3385)
# epoch 011 loss=1.0930 val_mIoU=0.3295 mAcc=0.3946 FWIoU=0.7256 (17.6s)
# epoch 012 loss=1.0691 val_mIoU=0.3512 mAcc=0.4296 FWIoU=0.7223 (17.8s)
#   -> saved best (mIoU=0.3512)
# epoch 013 loss=1.0410 val_mIoU=0.3450 mAcc=0.4327 FWIoU=0.7329 (17.8s)
# epoch 014 loss=1.0195 val_mIoU=0.3435 mAcc=0.4238 FWIoU=0.7173 (17.9s)
# epoch 066 loss=0.4287 val_mIoU=0.4784 mAcc=0.5459 FWIoU=0.7914 (17.8s)
# epoch 067 loss=0.4169 val_mIoU=0.4764 mAcc=0.5465 FWIoU=0.7925 (17.5s)
# epoch 068 loss=0.4179 val_mIoU=0.4765 mAcc=0.5452 FWIoU=0.7912 (17.8s)
# epoch 069 loss=0.4229 val_mIoU=0.4776 mAcc=0.5450 FWIoU=0.7917 (17.8s)
# epoch 070 loss=0.4142 val_mIoU=0.4790 mAcc=0.5484 FWIoU=0.7915 (17.5s)
# epoch 071 loss=0.4127 val_mIoU=0.4777 mAcc=0.5470 FWIoU=0.7926 (17.5s)
# epoch 072 loss=0.4106 val_mIoU=0.4788 mAcc=0.5502 FWIoU=0.7916 (17.8s)
# epoch 073 loss=0.4050 val_mIoU=0.4739 mAcc=0.5407 FWIoU=0.7913 (17.7s)
# epoch 074 loss=0.4101 val_mIoU=0.4742 mAcc=0.5395 FWIoU=0.7917 (17.7s)
# epoch 075 loss=0.4061 val_mIoU=0.4777 mAcc=0.5466 FWIoU=0.7919 (17.7s)
# epoch 076 loss=0.4107 val_mIoU=0.4776 mAcc=0.5455 FWIoU=0.7915 (17.8s)
# epoch 077 loss=0.4068 val_mIoU=0.4765 mAcc=0.5430 FWIoU=0.7914 (17.7s)
# epoch 078 loss=0.4107 val_mIoU=0.4779 mAcc=0.5479 FWIoU=0.7921 (17.7s)
# epoch 079 loss=0.4098 val_mIoU=0.4764 mAcc=0.5428 FWIoU=0.7923 (17.5s)
# [fmb-train] done. best val mIoU = 0.4834
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ updating run metadata (0.5s)
# wandb: ⣯ updating run metadata (0.5s)
# wandb: ⣟ updating run metadata (0.5s)
# wandb: ⡿ updating run metadata (0.5s)
# wandb: ⢿ updating run metadata (0.5s)
# wandb: ⣻ Finishing up...
# wandb: ⣽ Finishing up...
# wandb: ⣾ Finishing up...
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ uploading output.log 6.5KB/6.5KB (0.3s)
# wandb: ⣟ uploading wandb-summary.json 293B/293B (0.3s)
# wandb: ⣟ uploading config.yaml 3.4KB/3.4KB (0.3s)
# wandb: ⡿ uploading output.log 6.5KB/6.5KB (0.3s)
# wandb: ⡿ uploading wandb-summary.json 293B/293B (0.3s)
# wandb: ⡿ uploading config.yaml 3.4KB/3.4KB (0.3s)
# wandb: ⢿ uploading output.log 6.5KB/6.5KB (0.3s)
# wandb: ⢿ uploading wandb-summary.json 293B/293B (0.3s)
# wandb: ⢿ uploading config.yaml 3.4KB/3.4KB (0.3s)
# wandb: ⣻ uploading output.log 6.5KB/6.5KB (0.3s)
# wandb: ⣻ uploading wandb-summary.json 293B/293B (0.3s)
# wandb: ⣻ uploading config.yaml 3.4KB/3.4KB (0.3s)
# wandb: ⣽ uploading output.log 6.5KB/6.5KB (0.3s)
# wandb: ⣽ uploading wandb-summary.json 293B/293B (0.3s)
# wandb: ⣽ uploading config.yaml 3.4KB/3.4KB (0.3s)
# wandb: ⣾ uploading history steps 78-79, summary, console lines 108-109 (0.2s)
# wandb: ⣷ uploading history steps 78-79, summary, console lines 108-109 (0.2s)
# wandb:
# wandb: Run history:
# wandb: epoch_time_s ▆▇▆▇▃▃▆▁▆▃▆█▁▄▆▂▃▅▆▅▅▅▇▆▁▁▆▆▃▅▇▂▇▆▂▄▅▅▇▅
# wandb:   train/loss █▅▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    val/FWIoU ▁▄▄▅▅▆▆▇▇▆▇▇▇▇▇▇████████████████████████
# wandb:     val/mAcc ▁▂▂▂▂▄▅▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇███▇▇███████████
# wandb:     val/mIoU ▁▁▂▂▄▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇██████████████████
# wandb:
# wandb: Run summary:
# wandb: best_val_mIoU 0.48345
# wandb:  epoch_time_s 17.53086
# wandb:    train/loss 0.4098
# wandb:     val/FWIoU 0.79232
# wandb:      val/mAcc 0.5428
# wandb:      val/mIoU 0.47643
# wandb:
# wandb: 🚀 View run v_only at: https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb/runs/u6apraec
# wandb: ⭐️ View project at: https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb
# wandb: Synced 5 W&B file(s), 0 media file(s), 52 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260609_233208-u6apraec/logs

# %%
# Step 2 - T-only teacher (clean reference, train/val from FMB/train only)
![ -f {CKPT}/t_only.pt ] && echo "[skip] {CKPT}/t_only.pt exists - reusing" || python -m digtor.train --dataset fmb --root {ROOT} --mode t_only --epochs {EPOCHS} --bs {BS} --height {H} --width {W} --base {BASE} --out {CKPT} {AMP} {LR} {IGNORE_BG} {WANDB} {SPEED}
# Out:
# [fmb-train] mode=t_only device=cuda size=(384,512)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: nguyenmaiductrong37 (nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ setting up run 6b6tcadm (0.0s)
# wandb: ⣻ setting up run 6b6tcadm (0.0s)
# wandb: ⣽ setting up run 6b6tcadm (0.0s)
# wandb: ⣾ setting up run 6b6tcadm (0.0s)
# wandb: ⣷ setting up run 6b6tcadm (0.5s)
# wandb: ⣯ setting up run 6b6tcadm (0.5s)
# wandb: ⣟ setting up run 6b6tcadm (0.5s)
# wandb: Tracking run with wandb version 0.27.1
# wandb: Run data is saved locally in /content/DiGToR/wandb/run-20260609_235742-6b6tcadm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run t_only
# wandb: ⭐️ View project at https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb
# wandb: 🚀 View run at https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb/runs/6b6tcadm
# [fmb-train] split: train=1092 val=128 test=280
# [fmb-train] torch.compile enabled
# W0609 23:57:54.988000 10066 torch/_inductor/utils.py:1731] [0/0] Not enough SMs to use max_autotune_gemm mode
# epoch 000 loss=2.6803 val_mIoU=0.1331 mAcc=0.1952 FWIoU=0.3691 (89.0s)
#   -> saved best (mIoU=0.1331)
# epoch 001 loss=1.8830 val_mIoU=0.1992 mAcc=0.2509 FWIoU=0.6045 (17.8s)
#   -> saved best (mIoU=0.1992)
# epoch 002 loss=1.6416 val_mIoU=0.1908 mAcc=0.2691 FWIoU=0.5472 (17.8s)
# epoch 003 loss=1.5145 val_mIoU=0.2223 mAcc=0.2853 FWIoU=0.6481 (17.7s)
#   -> saved best (mIoU=0.2223)
# epoch 004 loss=1.4254 val_mIoU=0.2420 mAcc=0.3015 FWIoU=0.6660 (17.7s)
#   -> saved best (mIoU=0.2420)
# epoch 005 loss=1.3552 val_mIoU=0.2737 mAcc=0.3392 FWIoU=0.6894 (17.7s)
#   -> saved best (mIoU=0.2737)
# epoch 006 loss=1.2983 val_mIoU=0.2847 mAcc=0.3565 FWIoU=0.6960 (17.4s)
#   -> saved best (mIoU=0.2847)
# epoch 007 loss=1.2445 val_mIoU=0.2926 mAcc=0.3712 FWIoU=0.6866 (17.7s)
#   -> saved best (mIoU=0.2926)
# epoch 008 loss=1.2171 val_mIoU=0.2772 mAcc=0.3717 FWIoU=0.6358 (17.5s)
# epoch 009 loss=1.1782 val_mIoU=0.2615 mAcc=0.3468 FWIoU=0.5992 (17.7s)
# epoch 010 loss=1.1662 val_mIoU=0.3285 mAcc=0.4004 FWIoU=0.7403 (17.6s)
#   -> saved best (mIoU=0.3285)
# epoch 011 loss=1.1240 val_mIoU=0.3309 mAcc=0.4020 FWIoU=0.7422 (17.5s)
#   -> saved best (mIoU=0.3309)
# epoch 012 loss=1.0940 val_mIoU=0.2975 mAcc=0.3727 FWIoU=0.6523 (17.8s)
# epoch 013 loss=1.0666 val_mIoU=0.3157 mAcc=0.3931 FWIoU=0.6932 (17.8s)
# epoch 014 loss=1.0593 val_mIoU=0.3266 mAcc=0.4072 FWIoU=0.7368 (17.6s)
# epoch 015 loss=1.0301 val_mIoU=0.3402 mAcc=0.4176 FWIoU=0.7468 (17.5s)
#   -> saved best (mIoU=0.3402)
# epoch 016 loss=1.0163 val_mIoU=0.3258 mAcc=0.4004 FWIoU=0.7166 (17.8s)
# epoch 017 loss=0.9958 val_mIoU=0.3369 mAcc=0.4208 FWIoU=0.7481 (17.6s)
# epoch 018 loss=0.9723 val_mIoU=0.3410 mAcc=0.4099 FWIoU=0.7407 (17.6s)
#   -> saved best (mIoU=0.3410)
# epoch 068 loss=0.4850 val_mIoU=0.4552 mAcc=0.5490 FWIoU=0.7890 (17.7s)
# epoch 069 loss=0.4745 val_mIoU=0.4515 mAcc=0.5519 FWIoU=0.7875 (17.6s)
# epoch 070 loss=0.4795 val_mIoU=0.4496 mAcc=0.5453 FWIoU=0.7875 (17.6s)
# epoch 071 loss=0.4748 val_mIoU=0.4514 mAcc=0.5446 FWIoU=0.7873 (17.7s)
# epoch 072 loss=0.4735 val_mIoU=0.4527 mAcc=0.5490 FWIoU=0.7884 (17.5s)
# epoch 073 loss=0.4686 val_mIoU=0.4528 mAcc=0.5452 FWIoU=0.7872 (17.7s)
# epoch 074 loss=0.4723 val_mIoU=0.4526 mAcc=0.5474 FWIoU=0.7891 (17.8s)
# epoch 075 loss=0.4745 val_mIoU=0.4524 mAcc=0.5468 FWIoU=0.7875 (17.6s)
# epoch 076 loss=0.4746 val_mIoU=0.4523 mAcc=0.5480 FWIoU=0.7883 (17.5s)
# epoch 077 loss=0.4722 val_mIoU=0.4524 mAcc=0.5456 FWIoU=0.7886 (17.8s)
# epoch 078 loss=0.4698 val_mIoU=0.4523 mAcc=0.5491 FWIoU=0.7875 (17.7s)
# epoch 079 loss=0.4703 val_mIoU=0.4501 mAcc=0.5443 FWIoU=0.7873 (17.8s)
# [fmb-train] done. best val mIoU = 0.4579
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ uploading wandb-summary.json 293B/293B (0.4s)
# wandb: ⣻ uploading config.yaml 3.4KB/3.4KB (0.4s)
# wandb: ⣻ uploading output.log 6.7KB/6.7KB (0.4s)
# wandb: ⣽ uploading wandb-summary.json 293B/293B (0.4s)
# wandb: ⣽ uploading config.yaml 3.4KB/3.4KB (0.4s)
# wandb: ⣽ uploading output.log 6.7KB/6.7KB (0.4s)
# wandb: ⣾ uploading wandb-summary.json 293B/293B (0.4s)
# wandb: ⣾ uploading config.yaml 3.4KB/3.4KB (0.4s)
# wandb: ⣾ uploading output.log 6.7KB/6.7KB (0.4s)
# wandb: ⣷ uploading wandb-summary.json 293B/293B (0.4s)
# wandb: ⣷ uploading config.yaml 3.4KB/3.4KB (0.4s)
# wandb: ⣷ uploading output.log 6.7KB/6.7KB (0.4s)
# wandb: ⣯ uploading wandb-summary.json 293B/293B (0.4s)
# wandb: ⣯ uploading config.yaml 3.4KB/3.4KB (0.4s)
# wandb: ⣯ uploading output.log 6.7KB/6.7KB (0.4s)
# wandb: ⣟ uploading wandb-summary.json 293B/293B (0.9s)
# wandb: ⣟ uploading output.log 6.7KB/6.7KB (0.9s)
# wandb: ⡿ uploading wandb-summary.json 293B/293B (0.9s)
# wandb: ⡿ uploading output.log 6.7KB/6.7KB (0.9s)
# wandb: ⢿ uploading wandb-summary.json 293B/293B (0.9s)
# wandb: ⢿ uploading output.log 6.7KB/6.7KB (0.9s)
# wandb: ⣻ uploading wandb-summary.json 293B/293B (0.9s)
# wandb: ⣻ uploading output.log 6.7KB/6.7KB (0.9s)
# wandb: ⣽ uploading wandb-summary.json 293B/293B (0.9s)
# wandb: ⣽ uploading output.log 6.7KB/6.7KB (0.9s)
# wandb: ⣾ uploading history steps 78-79, summary, console lines 114-115 (0.1s)
# wandb: ⣷ uploading history steps 78-79, summary, console lines 114-115 (0.1s)
# wandb:
# wandb: Run history:
# wandb: epoch_time_s ▆▆▄▅▁▆▂▄▃▅▄▅▆▅▆▆▃▅▄▄▅▆▂▁▅▂▅▆▇▅▃▇▇█▆▃▄▂▅▄
# wandb:   train/loss █▇▇▇▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    val/FWIoU ▁▄▆▆▆▅▇▆▆▇▇▇▇▇▇▇██▇█████████████████████
# wandb:     val/mAcc ▁▁▂▃▃▄▄▄▄▄▄▅▅▆▆▆▆▆▇▇█▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇
# wandb:     val/mIoU ▁▁▂▄▃▅▅▅▆▆▆▆▇▆▆▇▇▇▇█████████████████████
# wandb:
# wandb: Run summary:
# wandb: best_val_mIoU 0.45785
# wandb:  epoch_time_s 17.81477
# wandb:    train/loss 0.4703
# wandb:     val/FWIoU 0.78725
# wandb:      val/mAcc 0.54433
# wandb:      val/mIoU 0.45012
# wandb:
# wandb: 🚀 View run t_only at: https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb/runs/6b6tcadm
# wandb: ⭐️ View project at: https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb
# wandb: Synced 5 W&B file(s), 0 media file(s), 64 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260609_235742-6b6tcadm/logs

# %%
# !git pull origin main
# Out:
# From https://github.com/nguyenmaiductrong/DiGToR
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# Step 3 - rescue detector (decision gate) on the held-out test split
# !python -m digtor.eval_detector --dataset fmb --root {ROOT} --height {H} --width {W} --base {BASE} --v_ckpt {CKPT}/v_only.pt --t_ckpt {CKPT}/t_only.pt --split test --out {RES}/detector.json
# Out:
# [Region counts on test]  (total valid pixels 55050240)
#   t_rescue    :     3136344  ( 5.70%)
#   v_preserve  :     4030391  ( 7.32%)
#   easy        :    43837861  (79.63%)
#   hard        :     4045644  ( 7.35%)
#
# [Detector] Thermal-Rescue detection
#   d_prob         AUROC=0.9407  AUPRC=0.3530
#   d_feat         AUROC=0.5832  AUPRC=0.0686
#   low_conf_v     AUROC=0.8766  AUPRC=0.2455
#   high_conf_t    AUROC=0.3177  AUPRC=0.0407
#   ent_v          AUROC=0.8753  AUPRC=0.2354
#   neg_ent_t      AUROC=0.3176  AUPRC=0.0406
#   fn_v           AUROC=0.3692  AUPRC=0.0425
#   fn_t           AUROC=0.3974  AUPRC=0.0439
#   dark_v         AUROC=0.5640  AUPRC=0.0782
#   LR(d_prob,c_v,c_t)       AUROC=0.9517  AUPRC=0.3995  coef=[7.457781442787463, -7.565130200254975, -1.8297277359185702]
#   LR(d_feat,c_v,c_t)       AUROC=0.8557  AUPRC=0.2285  coef=[1.9678851242479791, -8.26660365819439, -1.4294666364826187]
#
# [Detector] Visible-Preserve detection (V right & T wrong)
#   d_prob         AUROC=0.9517
#   d_feat         AUROC=0.5781
#   low_conf_v     AUROC=0.7106
#   high_conf_t    AUROC=0.1571
#   ent_v          AUROC=0.7110
#   neg_ent_t      AUROC=0.1587
#   fn_v           AUROC=0.4138
#   fn_t           AUROC=0.4261
#   dark_v         AUROC=0.5121
#
# [Detector] Hard-region detection (both wrong -> needs joint fusion)
#   d_prob         AUROC=0.8109
#   d_feat         AUROC=0.5773
#   low_conf_v     AUROC=0.8473
#   high_conf_t    AUROC=0.1779
#   ent_v          AUROC=0.8523
#   neg_ent_t      AUROC=0.1723
#   fn_v           AUROC=0.4176
#   fn_t           AUROC=0.4179
#   dark_v         AUROC=0.5721
#
# Saved -> results_fmb/detector.json
#
# [Decision gate]
#   best baseline : AUROC=0.8766  AUPRC=0.2455
#   best DiGToR   : AUROC=0.9517  AUPRC=0.3995
#   PASS: DiGToR signals beat baselines on BOTH AUROC and AUPRC.

# %%
# Step 4 - Fusion baseline (same corruption augmentation for a fair MFR comparison)
![ -f {CKPT}/fusion.pt ] && echo "[skip] {CKPT}/fusion.pt exists - reusing" || python -m digtor.train --dataset fmb --root {ROOT} --mode fusion --epochs {EPOCHS} --bs {BS} --height {H} --width {W} --base {BASE} --out {CKPT} {AMP} {LR} {IGNORE_BG} {WANDB} {SPEED} {CORRUPT}
# Out:
# [fmb-train] mode=fusion device=cuda size=(384,512)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: nguyenmaiductrong37 (nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ setting up run ctwokuzh (0.0s)
# wandb: ⣻ setting up run ctwokuzh (0.0s)
# wandb: ⣽ setting up run ctwokuzh (0.0s)
# wandb: ⣾ setting up run ctwokuzh (0.0s)
# wandb: ⣷ setting up run ctwokuzh (0.5s)
# wandb: ⣯ setting up run ctwokuzh (0.5s)
# wandb: ⣟ setting up run ctwokuzh (0.5s)
# wandb: ⡿ setting up run ctwokuzh (0.5s)
# wandb: ⢿ setting up run ctwokuzh (0.5s)
# wandb: Tracking run with wandb version 0.27.1
# wandb: Run data is saved locally in /content/DiGToR/wandb/run-20260610_002339-ctwokuzh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fusion
# wandb: ⭐️ View project at https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb
# wandb: 🚀 View run at https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb/runs/ctwokuzh
# [fmb-train] split: train=1092 val=128 test=280
# [fmb-train] torch.compile enabled
# W0610 00:23:54.652000 16694 torch/_inductor/utils.py:1731] [0/0] Not enough SMs to use max_autotune_gemm mode
# epoch 000 loss=2.4285 val_mIoU=0.1667 mAcc=0.2287 FWIoU=0.5042 (125.5s)
#   -> saved best (mIoU=0.1667)
# epoch 001 loss=1.8340 val_mIoU=0.1724 mAcc=0.2407 FWIoU=0.5344 (25.5s)
#   -> saved best (mIoU=0.1724)
# epoch 002 loss=1.6339 val_mIoU=0.1957 mAcc=0.2516 FWIoU=0.5904 (25.3s)
#   -> saved best (mIoU=0.1957)
# epoch 003 loss=1.4996 val_mIoU=0.2067 mAcc=0.2646 FWIoU=0.6111 (25.3s)
#   -> saved best (mIoU=0.2067)
# epoch 004 loss=1.4030 val_mIoU=0.2319 mAcc=0.3024 FWIoU=0.6671 (25.1s)
#   -> saved best (mIoU=0.2319)
# epoch 005 loss=1.3460 val_mIoU=0.2368 mAcc=0.2998 FWIoU=0.6608 (25.1s)
#   -> saved best (mIoU=0.2368)
# epoch 006 loss=1.2992 val_mIoU=0.2370 mAcc=0.2997 FWIoU=0.6500 (25.2s)
#   -> saved best (mIoU=0.2370)
# epoch 007 loss=1.2600 val_mIoU=0.2140 mAcc=0.3014 FWIoU=0.4589 (25.3s)
# epoch 008 loss=1.2229 val_mIoU=0.2694 mAcc=0.3453 FWIoU=0.6738 (25.0s)
#   -> saved best (mIoU=0.2694)
# epoch 009 loss=1.1604 val_mIoU=0.3129 mAcc=0.3833 FWIoU=0.7281 (25.0s)
#   -> saved best (mIoU=0.3129)
# epoch 010 loss=1.1232 val_mIoU=0.3663 mAcc=0.4352 FWIoU=0.7423 (25.2s)
#   -> saved best (mIoU=0.3663)
# epoch 011 loss=1.0983 val_mIoU=0.3685 mAcc=0.4687 FWIoU=0.7282 (25.2s)
#   -> saved best (mIoU=0.3685)
# epoch 012 loss=1.0799 val_mIoU=0.3482 mAcc=0.4432 FWIoU=0.6919 (24.9s)
# epoch 013 loss=1.0436 val_mIoU=0.3910 mAcc=0.4728 FWIoU=0.7515 (25.3s)
#   -> saved best (mIoU=0.3910)
# epoch 014 loss=1.0295 val_mIoU=0.3939 mAcc=0.4655 FWIoU=0.7581 (25.4s)
#   -> saved best (mIoU=0.3939)
# epoch 015 loss=0.9932 val_mIoU=0.3934 mAcc=0.4651 FWIoU=0.7612 (25.4s)
# epoch 016 loss=0.9916 val_mIoU=0.3885 mAcc=0.4631 FWIoU=0.7516 (25.3s)
# epoch 017 loss=0.9686 val_mIoU=0.4015 mAcc=0.4738 FWIoU=0.7719 (25.4s)
#   -> saved best (mIoU=0.4015)
# epoch 018 loss=0.9477 val_mIoU=0.3905 mAcc=0.4736 FWIoU=0.7620 (25.0s)
# epoch 019 loss=0.9169 val_mIoU=0.4186 mAcc=0.4868 FWIoU=0.7823 (25.4s)
#   -> saved best (mIoU=0.4186)
# epoch 020 loss=0.9022 val_mIoU=0.4192 mAcc=0.4845 FWIoU=0.7755 (25.0s)
# epoch 070 loss=0.4599 val_mIoU=0.5183 mAcc=0.6002 FWIoU=0.8200 (25.2s)
#   -> saved best (mIoU=0.5183)
# epoch 071 loss=0.4678 val_mIoU=0.5153 mAcc=0.5975 FWIoU=0.8207 (25.1s)
# epoch 072 loss=0.4645 val_mIoU=0.5185 mAcc=0.6009 FWIoU=0.8207 (25.3s)
#   -> saved best (mIoU=0.5185)
# epoch 073 loss=0.4538 val_mIoU=0.5197 mAcc=0.6005 FWIoU=0.8220 (25.2s)
#   -> saved best (mIoU=0.5197)
# epoch 074 loss=0.4551 val_mIoU=0.5178 mAcc=0.6004 FWIoU=0.8202 (25.3s)
# epoch 075 loss=0.4636 val_mIoU=0.5179 mAcc=0.5975 FWIoU=0.8213 (25.3s)
# epoch 076 loss=0.4686 val_mIoU=0.5180 mAcc=0.6014 FWIoU=0.8214 (25.4s)
# epoch 077 loss=0.4636 val_mIoU=0.5193 mAcc=0.6015 FWIoU=0.8213 (25.1s)
# epoch 078 loss=0.4607 val_mIoU=0.5182 mAcc=0.5988 FWIoU=0.8207 (25.2s)
# epoch 079 loss=0.4566 val_mIoU=0.5200 mAcc=0.6040 FWIoU=0.8213 (25.2s)
#   -> saved best (mIoU=0.5200)
# [fmb-train] done. best val mIoU = 0.5200
# wandb: ⢿ uploading artifact fusion-ckpt (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact fusion-ckpt (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact fusion-ckpt (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact fusion-ckpt (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact fusion-ckpt (0.5s)
# wandb: ⣯ uploading artifact fusion-ckpt (0.5s)
# wandb: ⣟ uploading artifact fusion-ckpt (0.5s)
# wandb: ⡿ uploading artifact fusion-ckpt (0.5s)
# wandb: ⢿ uploading artifact fusion-ckpt (0.5s)
# wandb: ⣻ uploading artifact fusion-ckpt (1.0s)
# wandb: ⣽ uploading artifact fusion-ckpt (1.0s)
# wandb: ⣾ uploading artifact fusion-ckpt (1.0s)
# wandb: ⣷ uploading artifact fusion-ckpt (1.0s)
# wandb: ⣯ uploading artifact fusion-ckpt (1.0s)
# wandb: ⣟ uploading artifact fusion-ckpt (1.5s)
# wandb:   ↳ ⣟ fusion.pt 1.1MB/50.4MB (0.3s)
# wandb: ⡿ uploading artifact fusion-ckpt (1.5s)
# wandb:   ↳ ⡿ fusion.pt 1.1MB/50.4MB (0.3s)
# wandb: ⢿ uploading artifact fusion-ckpt (1.5s)
# wandb:   ↳ ⢿ fusion.pt 1.1MB/50.4MB (0.3s)
# wandb: ⣻ uploading artifact fusion-ckpt (1.5s)
# wandb:   ↳ ⣻ fusion.pt 1.1MB/50.4MB (0.3s)
# wandb: ⣽ uploading artifact fusion-ckpt (1.5s)
# wandb:   ↳ ⣽ fusion.pt 1.1MB/50.4MB (0.3s)
# wandb: ⣾ uploading artifact fusion-ckpt (2.0s)
# wandb: ⢿ uploading wandb-summary.json 291B/291B (0.3s)
# wandb: ⢿ uploading config.yaml 3.5KB/3.5KB (0.3s)
# wandb: ⣻ uploading artifact fusion-ckpt (5.5s)
# wandb:   ↳ ⣻ fusion.pt 48.0MB/50.4MB (4.3s)
# wandb: ⣻ uploading output.log 6.9KB/6.9KB (0.3s)
# wandb: ⣻ uploading wandb-summary.json 291B/291B (0.3s)
# wandb: ⣻ uploading config.yaml 3.5KB/3.5KB (0.3s)
# wandb: ⣽ uploading artifact fusion-ckpt (5.5s)
# wandb:   ↳ ⣽ fusion.pt 48.0MB/50.4MB (4.3s)
# wandb: ⣽ uploading output.log 6.9KB/6.9KB (0.3s)
# wandb: ⣽ uploading wandb-summary.json 291B/291B (0.3s)
# wandb: ⣽ uploading config.yaml 3.5KB/3.5KB (0.3s)
# wandb: ⣾ uploading artifact fusion-ckpt (6.0s)
# wandb: ⣾ uploading output.log 6.9KB/6.9KB (0.8s)
# wandb: ⣾ uploading wandb-summary.json 291B/291B (0.8s)
# wandb: ⣾ uploading config.yaml 3.5KB/3.5KB (0.8s)
# wandb: ⣷ uploading artifact fusion-ckpt (6.0s)
# wandb: ⣷ uploading output.log 6.9KB/6.9KB (0.8s)
# wandb: ⣷ uploading wandb-summary.json 291B/291B (0.8s)
# wandb: ⣷ uploading config.yaml 3.5KB/3.5KB (0.8s)
# wandb: ⣯ uploading artifact fusion-ckpt (6.0s)
# wandb: ⣯ uploading output.log 6.9KB/6.9KB (0.8s)
# wandb: ⣯ uploading wandb-summary.json 291B/291B (0.8s)
# wandb: ⣯ uploading config.yaml 3.5KB/3.5KB (0.8s)
# wandb: ⣟ uploading artifact fusion-ckpt (6.0s)
# wandb: ⣟ uploading output.log 6.9KB/6.9KB (0.8s)
# wandb: ⣟ uploading wandb-summary.json 291B/291B (0.8s)
# wandb: ⣟ uploading config.yaml 3.5KB/3.5KB (0.8s)
# wandb: ⡿ uploading artifact fusion-ckpt (6.0s)
# wandb: ⡿ uploading output.log 6.9KB/6.9KB (0.8s)
# wandb: ⡿ uploading wandb-summary.json 291B/291B (0.8s)
# wandb: ⡿ uploading config.yaml 3.5KB/3.5KB (0.8s)
# wandb: ⢿ uploading artifact fusion-ckpt (6.5s)
# wandb: ⢿ uploading output.log 6.9KB/6.9KB (1.3s)
# wandb: ⢿ uploading wandb-summary.json 291B/291B (1.3s)
# wandb: ⢿ uploading config.yaml 3.5KB/3.5KB (1.3s)
# wandb: ⣻ uploading artifact fusion-ckpt (6.5s)
# wandb: ⣻ uploading output.log 6.9KB/6.9KB (1.3s)
# wandb: ⣻ uploading wandb-summary.json 291B/291B (1.3s)
# wandb: ⣻ uploading config.yaml 3.5KB/3.5KB (1.3s)
# wandb: ⣽ uploading artifact fusion-ckpt (6.5s)
# wandb: ⣽ uploading output.log 6.9KB/6.9KB (1.3s)
# wandb: ⣽ uploading wandb-summary.json 291B/291B (1.3s)
# wandb: ⣽ uploading config.yaml 3.5KB/3.5KB (1.3s)
# wandb: ⣾ uploading artifact fusion-ckpt (6.5s)
# wandb: ⣾ uploading output.log 6.9KB/6.9KB (1.3s)
# wandb: ⣾ uploading wandb-summary.json 291B/291B (1.3s)
# wandb: ⣾ uploading config.yaml 3.5KB/3.5KB (1.3s)
# wandb: ⣷ uploading artifact fusion-ckpt (6.5s)
# wandb: ⣷ uploading output.log 6.9KB/6.9KB (1.3s)
# wandb: ⣷ uploading wandb-summary.json 291B/291B (1.3s)
# wandb: ⣷ uploading config.yaml 3.5KB/3.5KB (1.3s)
# wandb: ⣯ uploading artifact fusion-ckpt (7.0s)
# wandb: ⣟ uploading artifact fusion-ckpt (7.0s)
# wandb: ⡿ uploading artifact fusion-ckpt (7.0s)
# wandb: ⢿ uploading artifact fusion-ckpt (7.0s)
# wandb: ⣻ uploading artifact fusion-ckpt (7.0s)
# wandb: ⣽ uploading artifact fusion-ckpt (7.5s)
# wandb: ⣾ uploading artifact fusion-ckpt (7.5s)
# wandb: ⣷ uploading artifact fusion-ckpt (7.5s)
# wandb: ⣯ uploading artifact fusion-ckpt (7.5s)
# wandb: ⣟ uploading artifact fusion-ckpt (7.5s)
# wandb: ⡿ uploading data (0.2s)
# wandb:
# wandb: Run history:
# wandb: epoch_time_s █▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   train/loss █▇▆▅▅▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:    val/FWIoU ▂▂▄▅▅▁▆▆▆▅▇▇▇▇▇▇████████████████████████
# wandb:     val/mAcc ▁▁▂▂▄▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█▇▇▇▇▇▇█▇▇██████
# wandb:     val/mIoU ▁▁▂▂▂▂▃▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇██████████
# wandb:
# wandb: Run summary:
# wandb: best_val_mIoU 0.51997
# wandb:  epoch_time_s 25.24781
# wandb:    train/loss 0.45665
# wandb:     val/FWIoU 0.82127
# wandb:      val/mAcc 0.60404
# wandb:      val/mIoU 0.51997
# wandb:
# wandb: 🚀 View run fusion at: https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb/runs/ctwokuzh
# wandb: ⭐️ View project at: https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb
# wandb: Synced 5 W&B file(s), 0 media file(s), 78 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260610_002339-ctwokuzh/logs

# %% [markdown]
# ### Step 5 - DiGToR Phase 0
#
# The restored configuration: a 3-path DiGToR router with V-trust, T-rescue, and Joint paths. The key fix is training the forced pure paths with hard segmentation loss (`force_path='v'/'t'`) plus teacher KD, so catastrophic single-modality failure can cut to a strong fallback path.

# %%
# Step 5 - DiGToR retrain with hard-seg-loss forced paths
![ -f {CKPT}/v_only.pt ] && [ -f {CKPT}/t_only.pt ] || echo 'WARN: missing teachers -> run Step 1/2 first'
![ -f {CKPT}/digtor.pt ] && echo "[skip] {CKPT}/digtor.pt exists - reusing" || python -m digtor.train --dataset fmb --root {ROOT} --mode digtor --epochs {DIGTOR_EPOCHS} --bs {BS} --height {H} --width {W} --base {BASE} --out {CKPT} --v_ckpt {CKPT}/v_only.pt --t_ckpt {CKPT}/t_only.pt {AMP} {LR} {IGNORE_BG} {WANDB} {SPEED} {CORRUPT} {GAMMA_PRIOR} {LAMBDA_COST} {ROUTE_BETA} {DISTILL} {NOGATE}

# Clean mIoU + rescue protocol + routing analyses on held-out FMB/test. rel_gate=0 at eval.
# !python -m digtor.eval_rescue --dataset fmb --root {ROOT} --height {H} --width {W} --base {BASE} --ckpt_dir {CKPT} --rel_gate 0 --out {RES}/eval_rescue.json {IGNORE_BG}
# Out:
# [fmb-train] mode=digtor device=cuda size=(384,512)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: nguyenmaiductrong37 (nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using an existing wandb-core service via WANDB_SERVICE.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ setting up run kvxfmim1 (0.0s)
# wandb: ⣻ setting up run kvxfmim1 (0.0s)
# wandb: ⣽ setting up run kvxfmim1 (0.0s)
# wandb: ⣾ setting up run kvxfmim1 (0.0s)
# wandb: ⣷ setting up run kvxfmim1 (0.5s)
# wandb: ⣯ setting up run kvxfmim1 (0.5s)
# wandb: ⣟ setting up run kvxfmim1 (0.5s)
# wandb: Tracking run with wandb version 0.27.1
# wandb: Run data is saved locally in /content/DiGToR/wandb/run-20260610_005939-kvxfmim1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run digtor
# wandb: ⭐️ View project at https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb
# wandb: 🚀 View run at https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb/runs/kvxfmim1
# [fmb-train] split: train=1092 val=128 test=280
# [digtor] loaded V teacher ckpt_fmb/v_only.pt
# [digtor] loaded T teacher ckpt_fmb/t_only.pt
# [fmb-train] torch.compile enabled
# W0610 01:00:03.288000 25870 torch/_inductor/utils.py:1731] [0/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/lowering.py:7836: UserWarning:
# Online softmax is disabled on the fly since Inductor decides to
# split the reduction. Cut an issue to PyTorch if this is an
# important use case and you want to speed it up with online
# softmax.
#
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/lowering.py:7836: UserWarning:
# Online softmax is disabled on the fly since Inductor decides to
# split the reduction. Cut an issue to PyTorch if this is an
# important use case and you want to speed it up with online
# softmax.
#
#   warnings.warn(
# epoch 000 loss=12.4183 val_mIoU=0.1755 mAcc=0.2445 FWIoU=0.5532 (368.2s) [{'seg': 1.9165785312652588, 'proj': -0.3388671875, 'rel': 1.376121997833252, 'ent': -1.0463892221450806, 'route': 0.32531967759132385, 'cost': 0.4104156494140625, 'distill': 13.308645248413086}] route[V=1.000 T=0.000 J=0.000] lam=1.000
#   -> saved best (mIoU=0.1755)
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/lowering.py:7836: UserWarning:
# Online softmax is disabled on the fly since Inductor decides to
# split the reduction. Cut an issue to PyTorch if this is an
# important use case and you want to speed it up with online
# softmax.
#
#   warnings.warn(
# epoch 001 loss=8.6892 val_mIoU=0.1927 mAcc=0.2549 FWIoU=0.5663 (171.6s) [{'seg': 1.513756275177002, 'proj': -0.3564453125, 'rel': 1.1351981163024902, 'ent': -0.9678276181221008, 'route': 0.12578685581684113, 'cost': 0.3975653052330017, 'distill': 9.984691619873047}] route[V=0.919 T=0.081 J=0.000] lam=1.000
#   -> saved best (mIoU=0.1927)
# epoch 002 loss=6.9788 val_mIoU=0.1989 mAcc=0.2675 FWIoU=0.6021 (87.9s) [{'seg': 1.3191277980804443, 'proj': -0.494873046875, 'rel': 1.1972768306732178, 'ent': -0.979971170425415, 'route': 0.15018230676651, 'cost': 0.4022732675075531, 'distill': 7.743898391723633}] route[V=0.826 T=0.146 J=0.028] lam=1.000
#   -> saved best (mIoU=0.1989)
# epoch 003 loss=6.2171 val_mIoU=0.2292 mAcc=0.2893 FWIoU=0.6642 (87.8s) [{'seg': 1.3531315326690674, 'proj': -0.4267578125, 'rel': 1.0488941669464111, 'ent': -0.9762812256813049, 'route': 0.13700972497463226, 'cost': 0.40367984771728516, 'distill': 7.930215358734131}] route[V=0.910 T=0.052 J=0.038] lam=1.000
#   -> saved best (mIoU=0.2292)
# epoch 004 loss=5.6745 val_mIoU=0.2346 mAcc=0.2953 FWIoU=0.6748 (87.6s) [{'seg': 1.350834846496582, 'proj': -0.51953125, 'rel': 1.2186498641967773, 'ent': -0.9714718461036682, 'route': 0.1919223815202713, 'cost': 0.3994620442390442, 'distill': 6.429201126098633}] route[V=0.877 T=0.075 J=0.048] lam=1.000
#   -> saved best (mIoU=0.2346)
# epoch 005 loss=5.3974 val_mIoU=0.2370 mAcc=0.2927 FWIoU=0.6828 (87.9s) [{'seg': 1.3451175689697266, 'proj': -0.484619140625, 'rel': 1.0606985092163086, 'ent': -0.9542361497879028, 'route': 0.19100868701934814, 'cost': 0.3958999812602997, 'distill': 6.621959686279297}] route[V=0.954 T=0.006 J=0.040] lam=1.000
#   -> saved best (mIoU=0.2370)
# epoch 006 loss=5.0613 val_mIoU=0.2559 mAcc=0.3196 FWIoU=0.6916 (87.9s) [{'seg': 1.4955341815948486, 'proj': -0.41748046875, 'rel': 1.396976351737976, 'ent': -0.9804896712303162, 'route': 0.26985928416252136, 'cost': 0.4010664224624634, 'distill': 7.346670627593994}] route[V=0.838 T=0.069 J=0.093] lam=1.000
#   -> saved best (mIoU=0.2559)
# epoch 007 loss=4.9268 val_mIoU=0.2830 mAcc=0.3414 FWIoU=0.7316 (87.8s) [{'seg': 1.1808760166168213, 'proj': -0.465576171875, 'rel': 0.9599004983901978, 'ent': -0.9134180545806885, 'route': 0.12960629165172577, 'cost': 0.3993299901485443, 'distill': 5.6008172035217285}] route[V=0.897 T=0.024 J=0.079] lam=1.000
# epoch 072 loss=1.9985 val_mIoU=0.5175 mAcc=0.6162 FWIoU=0.8198 (88.1s) [{'seg': 0.42280545830726624, 'proj': -0.5361328125, 'rel': 0.84891277551651, 'ent': -0.673987865447998, 'route': 0.11539453268051147, 'cost': 0.373418927192688, 'distill': 1.483940839767456}] route[V=0.825 T=0.052 J=0.122] lam=1.000
# epoch 073 loss=1.9834 val_mIoU=0.5193 mAcc=0.6132 FWIoU=0.8201 (88.1s) [{'seg': 0.45280879735946655, 'proj': -0.50830078125, 'rel': 1.1488473415374756, 'ent': -0.8061156272888184, 'route': 0.17266054451465607, 'cost': 0.37837010622024536, 'distill': 2.4399404525756836}] route[V=0.833 T=0.045 J=0.122] lam=1.000
# epoch 074 loss=1.9491 val_mIoU=0.5176 mAcc=0.6167 FWIoU=0.8192 (88.1s) [{'seg': 0.3940420150756836, 'proj': -0.5205078125, 'rel': 1.0230616331100464, 'ent': -0.751505970954895, 'route': 0.12067452073097229, 'cost': 0.3777833580970764, 'distill': 1.9094634056091309}] route[V=0.833 T=0.048 J=0.119] lam=1.000
# epoch 075 loss=2.0096 val_mIoU=0.5206 mAcc=0.6113 FWIoU=0.8194 (88.0s) [{'seg': 0.3558270335197449, 'proj': -0.52978515625, 'rel': 0.9743543267250061, 'ent': -0.7237467765808105, 'route': 0.1420438438653946, 'cost': 0.3731432557106018, 'distill': 1.6630890369415283}] route[V=0.819 T=0.056 J=0.125] lam=1.000
# epoch 076 loss=1.9855 val_mIoU=0.5196 mAcc=0.6089 FWIoU=0.8199 (88.0s) [{'seg': 0.35303083062171936, 'proj': -0.5107421875, 'rel': 0.9204821586608887, 'ent': -0.759628415107727, 'route': 0.11453888565301895, 'cost': 0.37588396668434143, 'distill': 1.679442048072815}] route[V=0.829 T=0.049 J=0.122] lam=1.000
# epoch 077 loss=2.0201 val_mIoU=0.5197 mAcc=0.6128 FWIoU=0.8192 (87.9s) [{'seg': 0.3383937478065491, 'proj': -0.49072265625, 'rel': 0.889197826385498, 'ent': -0.7640900611877441, 'route': 0.1284780353307724, 'cost': 0.37583500146865845, 'distill': 1.6113862991333008}] route[V=0.809 T=0.071 J=0.121] lam=1.000
# epoch 078 loss=1.9860 val_mIoU=0.5216 mAcc=0.6161 FWIoU=0.8204 (88.0s) [{'seg': 0.3648088276386261, 'proj': -0.51953125, 'rel': 0.9433724880218506, 'ent': -0.7157880067825317, 'route': 0.1032632365822792, 'cost': 0.37214967608451843, 'distill': 1.6131603717803955}] route[V=0.831 T=0.049 J=0.120] lam=1.000
# epoch 079 loss=1.9691 val_mIoU=0.5147 mAcc=0.6147 FWIoU=0.8194 (88.2s) [{'seg': 0.40053367614746094, 'proj': -0.52783203125, 'rel': 1.1944345235824585, 'ent': -0.79628586769104, 'route': 0.18430209159851074, 'cost': 0.3796580135822296, 'distill': 2.036123275756836}] route[V=0.825 T=0.061 J=0.114] lam=1.000
# [fmb-train] done. best val mIoU = 0.5224
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ updating run metadata (0.5s)
# wandb: ⣯ updating run metadata (0.5s)
# wandb: ⣟ updating run metadata (0.5s)
# wandb: ⡿ updating run metadata (0.5s)
# wandb: ⢿ updating run metadata (0.5s)
# wandb: ⣻ uploading output.log 26.3KB/26.3KB (0.1s)
# wandb: ⣻ uploading wandb-summary.json 377B/377B (0.1s)
# wandb: ⣻ uploading config.yaml 3.9KB/3.9KB (0.1s)
# wandb: ⣽ uploading output.log 26.3KB/26.3KB (0.1s)
# wandb: ⣽ uploading wandb-summary.json 377B/377B (0.1s)
# wandb: ⣽ uploading config.yaml 3.9KB/3.9KB (0.1s)
# wandb: ⣾ uploading output.log 26.3KB/26.3KB (0.1s)
# wandb: ⣾ uploading wandb-summary.json 377B/377B (0.1s)
# wandb: ⣾ uploading config.yaml 3.9KB/3.9KB (0.1s)
# wandb: ⣷ uploading output.log 26.3KB/26.3KB (0.1s)
# wandb: ⣷ uploading wandb-summary.json 377B/377B (0.1s)
# wandb: ⣷ uploading config.yaml 3.9KB/3.9KB (0.1s)
# wandb: ⣯ uploading output.log 26.3KB/26.3KB (0.1s)
# wandb: ⣯ uploading wandb-summary.json 377B/377B (0.1s)
# wandb: ⣯ uploading config.yaml 3.9KB/3.9KB (0.1s)
# wandb: ⣟ uploading output.log 26.3KB/26.3KB (0.6s)
# wandb: ⡿ uploading output.log 26.3KB/26.3KB (0.6s)
# wandb: ⢿ uploading output.log 26.3KB/26.3KB (0.6s)
# wandb: ⣻ uploading output.log 26.3KB/26.3KB (0.6s)
# wandb: ⣽ uploading output.log 26.3KB/26.3KB (0.6s)
# wandb: ⣾ uploading output.log 26.3KB/26.3KB (1.1s)
# wandb: ⣷ uploading output.log 26.3KB/26.3KB (1.1s)
# wandb: ⣯ uploading output.log 26.3KB/26.3KB (1.1s)
# wandb: ⣟ uploading output.log 26.3KB/26.3KB (1.1s)
# wandb: ⡿ uploading output.log 26.3KB/26.3KB (1.1s)
# wandb: ⢿ uploading history steps 78-79, summary, console lines 139-140 (0.2s)
# wandb: ⣻ uploading history steps 78-79, summary, console lines 139-140 (0.2s)
# wandb:
# wandb: Run history:
# wandb: epoch_time_s █▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      route/J ▁▂▁▄▄▅▁▅▃▆▄▄▅█▅▃▃▆█▅█▄▆▆▅▇▅▆▇▆▆▆▇▇▆▆▆▆▆▆
# wandb:      route/T ▅█▃▄▁▃▂▃▄▅▂▃▃▃▄▂▃▃▄▃▄▃▄▄▄▃▂▄▄▃▄▄▄▃▃▄▃▃▃▄
# wandb:      route/V █▃▅▄▇▄▄▃▃▄▃▂▅▁▄▃▅▄▄▃▃▂▃▂▃▄▄▃▄▃▃▃▃▂▃▃▂▃▃▃
# wandb:   train/loss █▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    val/FWIoU ▁▂▄▄▄▆▆▆▅▆▇▇▇▇▇▇█▇██████████████████████
# wandb:     val/mAcc ▁▂▂▂▃▃▄▄▄▄▅▆▅▆▆▆▆▆▇▇▇▇▇█████████████████
# wandb:     val/mIoU ▁▁▂▂▃▄▄▄▄▄▅▆▆▆▆▆▆▇▇▇▇█▇█████████████████
# wandb:
# wandb: Run summary:
# wandb: best_val_mIoU 0.52244
# wandb:  epoch_time_s 88.16906
# wandb:       route/J 0.11404
# wandb:       route/T 0.06124
# wandb:       route/V 0.82472
# wandb:    train/loss 1.96912
# wandb:     val/FWIoU 0.81939
# wandb:      val/mAcc 0.61466
# wandb:      val/mIoU 0.51468
# wandb:
# wandb: 🚀 View run digtor at: https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb/runs/kvxfmim1
# wandb: ⭐️ View project at: https://wandb.ai/nguyenmaiductrong37-h-c-vi-n-c-ng-ngh-b-u-ch-nh-vi-n-th-ng/digtor-fmb
# wandb: Synced 5 W&B file(s), 0 media file(s), 68 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260610_005939-kvxfmim1/logs
#
# [Eval] Segmentation (test split)
#   model      mIoU     mAcc     FWIoU
#   v_only    0.4738  0.5530  0.7739
#   t_only    0.4299  0.5106  0.7520
#   fusion    0.5066  0.5839  0.8021
#   digtor    0.5024  0.5699  0.7963
#
# [Eval] Thermal Rescue Protocol (v_only & t_only references)
#   fusion  TRR=0.6152 VPR=0.7681 HRR=0.1591 EasyAcc=0.9823
#           counts t_rescue=3136303 v_preserve=4030378 hard=4045670 easy=43837889
#   digtor  TRR=0.6068 VPR=0.7608 HRR=0.1527 EasyAcc=0.9834
#           counts t_rescue=3136303 v_preserve=4030378 hard=4045670 easy=43837889
#
# [Routing] Routing-rescue alignment (% of region routed to each path)
#   region          V-trust  T-rescue     Joint
#   t_rescue         50.50     20.57     28.93
#   v_preserve       62.06      7.49     30.44
#   easy             90.94      2.25      6.82
#   hard             46.76     11.87     41.38
#
# [Condition] Condition-aware routing (path allocation %, proxy conditions)
#   condition (n)       V-trust  T-rescue     Joint   mIoU
#   daylight(78)          85.56      1.90     12.54   0.4742
#   fog(81)               83.24      4.33     12.44   0.5475
#   lowlight(12)          80.44      6.84     12.72   0.3709
#   other(109)            81.98      5.93     12.09   0.4841
#   Expected emergent behaviour: more T-rescue under lowlight/fog,
#   more V-trust under daylight, without any condition supervision.
#
# [Day/Night] Day/Night routing shift (median-luminance split, no supervision)
#   split (median lum=0.487)    V-trust  T-rescue     Joint
#   day (bright)              85.40      2.37     12.23
#   night (dark)              81.15      6.40     12.46
#   T-rescue share day-vs-night diff=0.0403  permutation p=0.0000
#
# Saved -> results_fmb/eval_rescue.json

# %%
# Step 6 - corruption robustness, FLOPs, and the modality-cut win check
# Dense-routing robustness table (no retrain).
# !python -m digtor.eval_robustness --dataset fmb --root {ROOT} --height {H} --width {W} --base {BASE} --ckpt_dir {CKPT} --rel_gate 0 --out {RES}/robustness.json {IGNORE_BG} {LIMIT_ARG}

# Route-share / FLOP accounting for the 3-path model.
# !python -m digtor.profile_flops --dataset fmb --root {ROOT} --ckpt {CKPT}/digtor.pt --base {BASE} --height {H} --width {W} --out {RES}/flops.json {LIMIT_ARG}

# Catastrophic-thermal check with realizable force_path cuts.
# !python -m digtor.eval_modality_cut --dataset fmb --root {ROOT} --height {H} --width {W} --base {BASE} --ckpt_dir {CKPT} --skips 0.3 0.5 0.6 --out {RES}/modality_cut.json {IGNORE_BG} {LIMIT_ARG}
# Out:
# [Robustness] mIoU under corruption
#   tag                     v_only    t_only    fusion    digtor
#   clean                   0.4738    0.4299    0.5066    0.5024
#   th_noise_0.3            0.4738    0.0194    0.4818    0.4891
#   th_noise_0.6            0.4738    0.0273    0.4662    0.4845
#   th_crossover_0.5        0.4738    0.3569    0.4930    0.4983
#   th_crossover_0.8        0.4738    0.2058    0.4700    0.4922
#   th_low_contrast         0.4738    0.2703    0.4810    0.4959
#   th_dropout              0.4738    0.0698    0.4404    0.4812
#   v_darken_0.6            0.3496    0.4299    0.4726    0.4751
#   v_noise_0.3             0.1780    0.4299    0.4908    0.4700
#   v_blur                  0.3573    0.4299    0.4853    0.4878
#   v_fog_0.5               0.3593    0.4299    0.4785    0.4786
#
# [Robustness] DiGToR routing signals under corruption (mean)
#   tag                         d      c_v      c_t
#   clean                  0.2000   0.9421   0.9048
#   th_noise_0.3           0.3923   0.9421   0.2089
#   th_noise_0.6           0.5678   0.9421   0.1766
#   th_crossover_0.5       0.2144   0.9421   0.7905
#   th_crossover_0.8       0.2788   0.9421   0.6296
#   th_low_contrast        0.2426   0.9421   0.6926
#   th_dropout             0.7550   0.9421   0.4775
#   v_darken_0.6           0.2213   0.8982   0.9048
#   v_noise_0.3            0.3337   0.4980   0.9048
#   v_blur                 0.3066   0.8502   0.9048
#   v_fog_0.5              0.2320   0.9001   0.9048
#   Hypothesis: under th_* corruption d stays high/rises while c_t falls.
#
# [Robustness] MFR (mean mIoU(corrupt)/mIoU(clean))
#   v_only   thermal-MFR=1.0000  visible-MFR=0.6566
#   t_only   thermal-MFR=0.3682  visible-MFR=1.0000
#   fusion   thermal-MFR=0.9318  visible-MFR=0.9510
#   digtor   thermal-MFR=0.9757  visible-MFR=0.9512
#
# Saved -> results_fmb/robustness.json
#
# === [FLOPs] Dense FLOPs @ 384x512, base=32 (batch 1) ===
#   v_only             72.699 GFLOPs
#   t_only             72.473 GFLOPs
#   fusion            102.255 GFLOPs
#   digtor (dense)    136.947 GFLOPs   = 1.34x fusion  <-- routing currently COSTS MORE
#   digtor force_v     81.559 GFLOPs   (single-encoder subgraph; the catastrophic-skip path)
#   digtor force_t    107.088 GFLOPs
#
# === [FLOPs] digtor dense component breakdown ===
#   enc_v              25.756 GFLOPs   ( 18.8% of digtor)
#   enc_t              25.529 GFLOPs   ( 18.6% of digtor)
#   paths              25.372 GFLOPs   ( 18.5% of digtor)
#   skips               6.442 GFLOPs   (  4.7% of digtor)
#   router_overhead     6.904 GFLOPs   (  5.0% of digtor)
#   dec                46.944 GFLOPs   ( 34.3% of digtor)
#   --> encoders = 37.4% of cost (NOT per-pixel skippable); paths+skips = 23.2% (per-token routable)
#
# === [FLOPs] route share (MEASURED on FMB test) ===
#   V-trust 0.833   T-rescue 0.044   Joint 0.124
#
# === [FLOPs] ACHIEVABLE FLOPs ===
#   (a) token-level path/skip routing :  114.068 GFLOPs   (16.7% vs digtor-dense, 1.12x fusion)
#       -> bounded by paths+skips share; encoders dominate -> small win.
#   (b) per-image single-encoder skip :   81.559 GFLOPs   (40.4% vs digtor-dense, 0.80x fusion)
#       -> the realistic C4 lever: dead-sensor / night->skip-thermal.
#
# === [FLOPs] latency (cuda, batch 1, 50 iters) ===
#   v_only              6.76 ms
#   t_only              6.85 ms
#   fusion             10.83 ms
#   digtor_dense       18.98 ms
#   digtor_force_v      7.76 ms
#   digtor_force_t     10.23 ms
#
# Saved -> results_fmb/flops.json
#
# [Modality-cut] mIoU per variant (cut vs soft vs fusion)
#   tag                 v_only   t_only   fusion   d_softd_skip0.3d_skip0.5d_skip0.6 d_oracle   d_BEST
#   clean               0.4738   0.4299   0.5066   0.5024   0.5024   0.5024   0.5024   0.5024   0.5024
#   th_noise_0.3        0.4738   0.0194   0.4818   0.4891   0.4854   0.4854   0.4854   0.4854   0.4891
#   th_noise_0.6        0.4738   0.0273   0.4662   0.4845   0.4854   0.4854   0.4854   0.4854   0.4854
#   th_dropout          0.4738   0.0698   0.4404   0.4812   0.4812   0.4854   0.4854   0.4854   0.4854
#   th_crossover_0.8    0.4738   0.2058   0.4700   0.4922   0.4922   0.4918   0.4890   0.4854   0.4922
#   th_low_contrast     0.4738   0.2703   0.4810   0.4959   0.4959   0.4959   0.4946   0.4854   0.4959
#   v_darken_0.6        0.3496   0.4299   0.4726   0.4751   0.4751   0.4751   0.4751   0.4267   0.4751
#   v_noise_0.3         0.1780   0.4299   0.4908   0.4700   0.4700   0.4494   0.4310   0.4267   0.4700
#   v_blur              0.3573   0.4299   0.4853   0.4878   0.4878   0.4878   0.4878   0.4267   0.4878
#   v_fog_0.5           0.3593   0.4299   0.4785   0.4786   0.4786   0.4786   0.4786   0.4267   0.4786
#
# [Modality-cut] reliability under corruption (mean)
#   clean             c_v=0.942  c_t=0.905
#   th_noise_0.3      c_v=0.942  c_t=0.209
#   th_noise_0.6      c_v=0.942  c_t=0.177
#   th_dropout        c_v=0.942  c_t=0.477
#   th_crossover_0.8  c_v=0.942  c_t=0.630
#   th_low_contrast   c_v=0.942  c_t=0.693
#   v_darken_0.6      c_v=0.898  c_t=0.905
#   v_noise_0.3       c_v=0.498  c_t=0.905
#   v_blur            c_v=0.850  c_t=0.905
#   v_fog_0.5         c_v=0.900  c_t=0.905
#
# ============================================================
# [Modality-cut] MODALITY-CUT VERDICT
# ============================================================
#   clean parity : d_soft 0.5024 vs fusion 0.5066  (delta=-0.0043)  OK
#   th_noise_0.6   : d_BEST 0.4854 vs fusion 0.4662 (delta=+0.0192) WIN   | path_v-cut 0.4854  v_only-cut 0.4738 (true ceiling delta=+0.0076)
#   th_dropout     : d_BEST 0.4854 vs fusion 0.4404 (delta=+0.0450) WIN   | path_v-cut 0.4854  v_only-cut 0.4738 (true ceiling delta=+0.0333)
#
#   >>> MODALITY-CUT PASS  (catastrophic cut beats fusion; clean parity)
#
# Saved -> results_fmb/modality_cut.json
